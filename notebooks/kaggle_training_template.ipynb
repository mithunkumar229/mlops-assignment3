# %% [markdown]
# # Kaggle Training Template\nEnable GPU and add Kaggle Secrets: `WANDB_API_KEY`, `HF_TOKEN`.

# %%
from kaggle_secrets import UserSecretsClient\nimport os, wandb\nfrom huggingface_hub import login\n\nsecrets = UserSecretsClient()\nos.environ['WANDB_API_KEY'] = secrets.get_secret('WANDB_API_KEY')\nos.environ['HF_TOKEN'] = secrets.get_secret('HF_TOKEN')\nlogin(token=os.environ['HF_TOKEN'])\nwandb.login(key=os.environ['WANDB_API_KEY'])\n

# %% [markdown]
# Upload/import this repository into Kaggle, then run `src/preprocess.py` and `src/train.py` from the notebook or copy the training cells here.
